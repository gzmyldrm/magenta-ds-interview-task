# %% [markdown]
# # Imports and definitions

# %% [markdown]
# # Table of Contents
#
# 1. [Imports and definitions](#imports-and-definitions)
# 2. [Load data](#load-data)
# 3. [Prepare data](#prepare-data)
# 4. [Define objectives](#define-objectives)
# 5. [Start tuning](#start-tuning)
# 6. [Conclusion](#conclusion)
#
# ---

# %%
from pathlib import Path
import time

import polars as pl
import numpy as np

import numpy as np
import xgboost as xgb
from sklearn.metrics import f1_score

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
import xgboost as xgb
from catboost import CatBoostClassifier
from sklearn.linear_model import RidgeClassifier, LogisticRegression
from sklearn.ensemble import StackingClassifier

import optuna

_ = pl.Config.set_tbl_cols(None)
_ = pl.Config.set_fmt_str_lengths(500)
_ = pl.Config.set_fmt_float("full")

# %%
import warnings
warnings.filterwarnings('ignore', category=RuntimeWarning, module='sklearn')

# %%
base_dir = Path('/workspaces/data-scientist-at-magenta')
code_dir = base_dir / 'notebooks'
data_dir = code_dir / "data"
features_dir = data_dir / 'features'
train_dir = data_dir / 'train'
db_dir = 'sqlite:///data/models/{}.db'

# %% [markdown]
# # Load data

# %%
# %%time

train_meta = pl.read_parquet(train_dir / 'data-meta-v0-50.parquet')
train = pl.read_parquet(train_dir / 'data-v0-80.parquet')
# Out:
# CPU times: user 19.4 ms, sys: 7.76 ms, total: 27.1 ms
# Wall time: 28.7 ms

# %% [markdown]
# # Prepare data

# %%
X_meta = train_meta.select(pl.exclude(['rating_account_id', 'customer_id', 'has_done_upselling']))
y_meta = train_meta.select('has_done_upselling')

# %%
X = train.select(pl.exclude(['rating_account_id', 'customer_id', 'has_done_upselling']))
y = train.select('has_done_upselling')

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# # Define objectives

# %%
def stacking_objective(trial, X, y, skf, base_models):
    # Define Ridge parameters to tune
    ridge_params = {
        'alpha': trial.suggest_float('alpha', 1e-4, 100.0, log=True),
        'solver': trial.suggest_categorical('solver', ['auto', 'svd', 'cholesky', 'lsqr']),
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced'])
    }
    
    # Create stacking classifier with Ridge meta-learner
    stacking_clf = StackingClassifier(
        estimators=base_models,  
        final_estimator=RidgeClassifier(**ridge_params),
        cv='prefit',  # No need for the base models to be trained
        stack_method='predict_proba'
    )
    
    cv_scores = []
    optimal_thresholds = []
    
    # Use the same cross-validation approach as base models
    for train_idx, valid_idx in skf.split(X, y):
        # Split data
        train_x, valid_x = X[train_idx], X[valid_idx] 
        train_y, valid_y = y[train_idx], y[valid_idx]
        
        # Train stacking classifier
        stacking_clf.fit(train_x.to_numpy(), train_y.to_numpy().ravel())
        
        # Get probabilities
        preds = stacking_clf.predict(valid_x.to_numpy())
        
        # Find optimal threshold using your existing function
        f1 = f1_score(valid_y.to_numpy().ravel(), preds)
        
        cv_scores.append(f1)
    
    return np.mean(cv_scores)

# %%
def stacking_logistic_objective(trial, X, y, skf, base_models):
    
    # Define Logistic Regression parameters to tune (simplified)
    logistic_params = {
        'C': trial.suggest_float('C', 1e-4, 100.0, log=True),
        'penalty': 'l2',  # Fixed to l2
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced']),
        'max_iter': trial.suggest_int('max_iter', 100, 1000)
        # solver will use default ('lbfgs' for small datasets)
    }
    
    # Create stacking classifier with Logistic Regression meta-learner
    stacking_clf = StackingClassifier(
        estimators=base_models,  
        final_estimator=LogisticRegression(**logistic_params),
        cv='prefit',  # No need for the base models to be trained
        stack_method='predict_proba'
    )
    
    cv_scores = []
    optimal_thresholds = []
    
    # Use the same cross-validation approach as base models
    for train_idx, valid_idx in skf.split(X, y):
        # Split data
        train_x, valid_x = X[train_idx], X[valid_idx] 
        train_y, valid_y = y[train_idx], y[valid_idx]
        
        # Train stacking classifier
        stacking_clf.fit(train_x.to_numpy(), train_y.to_numpy().ravel())
        
        # Get predictions
        preds = stacking_clf.predict(valid_x.to_numpy())
        
        # Calculate F1 score
        f1 = f1_score(valid_y.to_numpy().ravel(), preds)
        
        cv_scores.append(f1)
    
    trial.set_user_attr('optimal_thresholds', optimal_thresholds)
    
    return np.mean(cv_scores)

# %% [markdown]
# # Start tuning

# %%
# Setup
n_trials = 100

xgb_study = optuna.load_study(
    study_name="xgboost_optimization",
    storage=db_dir.format('xgb_study')
)
rf_study = optuna.load_study(
    study_name="random_forest_optimization_basef1",
    storage=db_dir.format('rf_study')
)
histgb_study = optuna.load_study(
    study_name="histgb_optimization",
    storage=db_dir.format('histgb_study')
)
cat_study = optuna.load_study(
    study_name="catboost_optimization",
    storage=db_dir.format('cat_study')
)

xgb_best_params = xgb_study.best_params
rf_best_params = rf_study.best_params
histgb_best_params = histgb_study.best_params
cat_best_params = cat_study.best_params

xgb_model = xgb.XGBClassifier(**xgb_best_params)
rf_model = RandomForestClassifier(**rf_best_params)
histgb_model = HistGradientBoostingClassifier(**histgb_best_params)
cat_model = CatBoostClassifier(**cat_best_params, verbose=0)

xgb_model.fit(X.to_numpy(), y.to_numpy().ravel())
rf_model.fit(X.to_numpy(), y.to_numpy().ravel())
histgb_model.fit(X.to_numpy(), y.to_numpy().ravel())
cat_model.fit(X.to_numpy(), y.to_numpy().ravel())

base_models = [
    ("xgb", xgb_model),
    ("rf", rf_model),
    ("histgb", histgb_model),
    ("cat", cat_model)
]

# %%
meta_study = optuna.create_study(
    study_name="meta_ridge_base_optimization",
    direction="maximize",
    storage=db_dir.format('meta_learners_study'),
    load_if_exists=True
)
meta_study.optimize(lambda trial: stacking_objective(trial, X_meta, y_meta, skf, base_models), n_trials=n_trials)
print(f"\nBest Stacking score: {meta_study.best_value}")
print(f"Best Stacking params: {meta_study.best_params}")
# Out:
# [I 2025-07-02 01:18:46,367] Using an existing study with name 'meta_ridge_base_optimization' instead of creating a new one.
# [I 2025-07-02 01:18:48,574] Trial 105 finished with value: 0.1581749565659604 and parameters: {'alpha': 0.012436062963279641, 'solver': 'svd', 'class_weight': 'balanced'}. Best is trial 22 with value: 0.1581749565659604.
# [I 2025-07-02 01:18:50,450] Trial 106 finished with value: 0.1581749565659604 and parameters: {'alpha': 0.01166932918496607, 'solver': 'svd', 'class_weight': 'balanced'}. Best is trial 22 with value: 0.1581749565659604.
# [I 2025-07-02 01:18:52,447] Trial 107 finished with value: 0.15798777173061912 and parameters: {'alpha': 0.0240754273765649, 'solver': 'svd', 'class_weight': 'balanced'}. Best is trial 22 with value: 0.1581749565659604.
# [I 2025-07-02 01:18:54,859] Trial 108 finished with value: 0.1571586081725586 and parameters: {'alpha': 0.007240289584056439, 'solver': 'svd', 'class_weight': 'balanced'}. Best is trial 22 with value: 0.1581749565659604.
# [I 2025-07-02 01:18:57,221] Trial 109 finished with value: 0.15722340771475407 and parameters: {'alpha': 0.003362118187154241, 'solver': 'cholesky', 'class_weight': 'balanced'}. Best is trial 22 with value: 0.1581749565659604.
# [I 2025-07-02 01:18:59,183] Trial 110 finished with value: 0.15814243691867352 and parameters: {'alpha': 0.01283669572633955, 'solver': 'svd', 'class_weight': 'balanced'}. Best is trial 22 with value: 0.1581749565659604.
# [I 2025-07-02 01:19:01,209] Trial 111 finished with value: 0.1571935719569622 and parameters: {'alpha': 0.004481263909026402, 'solver': 'svd', 'class_weight': 'balanced'}. Best is trial 22 with value: 0.1581749565659604.
# [I 2025-07-02 01:19:03,127] Trial 112 finished with value: 0.15747887922191797 and parameters: {'alpha': 0.009871103934330397, 'solver': 'svd', 'class_weight': 'balanced'}. Best is trial 22 with value: 0.1581749565659604.
# [I 2025-07-02 01:19:05,022] Trial 113 finished with value: 0.15814243691867352 and parameters: {'alpha': 0.013901117568959093, 'solver': 'svd', 'class_weight': 'balanced'}. Best is trial 22 with value: 0.1581749565659604.
# [I 2025-07-02 01:19:06,971] Trial 114 finished with value: 0.15798777173061912 and parameters: {'alpha': 0.02520617837440587, 'solver': 'svd', 'class_weight': 'balanced'}. Best is trial 22 with value: 0.1581749565659604.
# [I 2025-07-02 01:19
 'solver': 'svd', 'class_weight': 'balanced'}. Best is trial 22 with value: 0.1581749565659604.
# [I 2025-07-02 01:21:59,430] Trial 204 finished with value: 0.1571586081725586 and parameters: {'alpha': 0.007914407076802878, 'solver': 'svd', 'class_weight': 'balanced'}. Best is trial 22 with value: 0.1581749565659604.
# Best Stacking score: 0.1581749565659604
# Best Stacking params: {'alpha': 0.011675306544253592, 'solver': 'svd', 'class_weight': 'balanced'}

# %%
meta_study = optuna.create_study(
    study_name="meta__logistic_base_optimization",
    direction="maximize",
    storage=db_dir.format('meta_learners_study'),
    load_if_exists=True
)
meta_study.optimize(lambda trial: stacking_logistic_objective(trial, X_meta, y_meta, skf, base_models), n_trials=n_trials)
print(f"\nBest Stacking score: {meta_study.best_value}")
print(f"Best Stacking params: {meta_study.best_params}")
# Out:
# [I 2025-07-02 01:12:09,665] A new study created in RDB with name: meta__logistic_base_optimization
# [I 2025-07-02 01:12:11,455] Trial 0 finished with value: 0.0 and parameters: {'C': 0.001215388901974338, 'class_weight': None, 'max_iter': 954}. Best is trial 0 with value: 0.0.
# [I 2025-07-02 01:12:13,250] Trial 1 finished with value: 0.0 and parameters: {'C': 2.166109755504578, 'class_weight': None, 'max_iter': 414}. Best is trial 0 with value: 0.0.
# [I 2025-07-02 01:12:15,221] Trial 2 finished with value: 0.154624044163239 and parameters: {'C': 0.42004714962249096, 'class_weight': 'balanced', 'max_iter': 306}. Best is trial 2 with value: 0.154624044163239.
# [I 2025-07-02 01:12:17,015] Trial 3 finished with value: 0.1560070220022802 and parameters: {'C': 20.034698103906024, 'class_weight': 'balanced', 'max_iter': 641}. Best is trial 3 with value: 0.1560070220022802.
# [I 2025-07-02 01:12:18,788] Trial 4 finished with value: 0.15462676533703168 and parameters: {'C': 0.42821333727256844, 'class_weight': 'balanced', 'max_iter': 612}. Best is trial 3 with value: 0.1560070220022802.
# [I 2025-07-02 01:12:20,548] Trial 5 finished with value: 0.0 and parameters: {'C': 0.00019043091294153498, 'class_weight': None, 'max_iter': 606}. Best is trial 3 with value: 0.1560070220022802.
# [I 2025-07-02 01:12:22,299] Trial 6 finished with value: 0.15664344871749242 and parameters: {'C': 0.7354517337823238, 'class_weight': 'balanced', 'max_iter': 193}. Best is trial 6 with value: 0.15664344871749242.
# [I 2025-07-02 01:12:24,068] Trial 7 finished with value: 0.0 and parameters: {'C': 0.014015328115845374, 'class_weight': None, 'max_iter': 266}. Best is trial 6 with value: 0.15664344871749242.
# [I 2025-07-02 01:12:25,871] Trial 8 finished with value: 0.15606881541194598 and parameters: {'C': 85.39950576669332, 'class_weight': 'balanced', 'max_iter': 682}. Best is trial 6 with value: 0.15664344871749242.
# [I 2025-07-02 01:12:27,617] Trial 9 finished with value: 0.0 and parameters: {'C': 23.622080167833335, 'class_weight': None, 'max_iter': 665}. Best is trial 6 with value: 0.15664344871749242.
# [I 2025-07-02 01:12:29,606] Trial 10 finished with value: 0.15411433521552148 and parameters: {'C': 0.02566973275608651, 'class_weight': 'balanced', 'max_iter': 105}. Best is trial 6 with value: 0.15664344871749242.
# [I 2025-07-02 01:12:31,394] Trial 11 finished with value: 0.15597358479038217 and parameters: {'C': 44.29711420091422, 'class_weight': 'balanced', 'max_iter': 844}. Best is trial 6 with value: 0.15664344871749242.
# [I 2025-07-02 01:12:33,419] Trial 12 finished with value: 0.15501609704018432 and parameters: {'C': 3.7704950642969686, 'class_weight': 'balanced', 'max_iter': 472}. Best is trial 6 with value: 0.15664344871749242.
# [I 2025-07-02 01:12:35,499] Trial 13 finished with value: 0.15606881541194598 and parameters: {'C': 73.65974524206096, 'class_weight': 'balanced', 'max_iter': 785}. Best is trial 6 with value: 0.15664344871749242.
# [I 2025-07-02 01:12:37,515] Trial 14 finished with value: 0.15488482695497177 and parameters: {'C': 3.190646441761759, 'class_weight': 'balanced', 'max_iter': 150}. Best is trial 6 with value: 0.15664344871749242.
# [I 2025-07-02 01:12
. Best is trial 21 with value: 0.15711548982121945.
# [I 2025-07-02 01:13:18,107] Trial 35 finished with value: 0.15432095593860584 and parameters: {'C': 0.05281770315490708, 'class_weight': 'balanced', 'max_iter': 305}. Best is trial 21 with value: 0.15711548982121945.
# [I 2025-07-02 01:13:20,097] Trial 36 finished with value: 0.0 and parameters: {'C': 2.1620985407650983, 'class_weight': None, 'max_iter': 253}. Best is trial 21 with value: 0.15711548982121945.
# [I 2025-07-02 01:13:22,163] Trial 37 finished with value: 0.15656894948369604 and parameters: {'C': 0.5783505950488006, 'class_weight': 'balanced', 'max_iter': 175}. Best is trial 21 with value: 0.15711548982121945.
# [I 2025-07-02 01:13:24,373] Trial 38 finished with value: 0.15592012011603998 and parameters: {'C': 8.542090494824023, 'class_weight': 'balanced', 'max_iter': 420}. Best is trial 21 with value: 0.15711548982121945.
# [I 2025-07-02 01:13:26,124] Trial 39 finished with value: 0.0 and parameters: {'C': 0.352056979690626, 'class_weight': None, 'max_iter': 340}. Best is trial 21 with value: 0.15711548982121945.
# [I 2025-07-02 01:13:28,117] Trial 40 finished with value: 0.15258512129576365 and parameters: {'C': 0.02105044898383194, 'class_weight': 'balanced', 'max_iter': 272}. Best is trial 21 with value: 0.15711548982121945.
# [I 2025-07-02 01:13:29,945] Trial 41 finished with value: 0.15473844030395806 and parameters: {'C': 0.11382400842910102, 'class_weight': 'balanced', 'max_iter': 415}. Best is trial 21 with value: 0.15711548982121945.
# [I 2025-07-02 01:13:31,780] Trial 42 finished with value: 0.1551780826959322 and parameters: {'C': 0.21110650874672413, 'class_weight': 'balanced', 'max_iter': 537}. Best is trial 21 with value: 0.15711548982121945.
# [I 2025-07-02 01:13:33,546] Trial 43 finished with value: 0.15515599058866741 and parameters: {'C': 1.9931619278056099, 'class_weight': 'balanced', 'max_iter': 398}. Best is trial 21 with value: 0.15711548982121945.
# [I 2025-07-02 01:13:35,322] Trial 44 finished with value: 0.15654011234145682 and parameters: {'C': 0.5844430655672933, 'class_weight': 'balanced', 'max_iter': 597}. Best is trial 21 with value: 0.15711548982121945.
# [I 2025-07-02 01:13:37,064] Trial 45 finished with value: 0.15719259140971192 and parameters: {'C': 0.13754162540171044, 'class_weight': 'balanced', 'max_iter': 458}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:13:38,813] Trial 46 finished with value: 0.15476386053480462 and parameters: {'C': 0.049543071641603396, 'class_weight': 'balanced', 'max_iter': 465}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:13:40,583] Trial 47 finished with value: 0.0 and parameters: {'C': 0.012732654179417591, 'class_weight': None, 'max_iter': 587}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:13:42,581] Trial 48 finished with value: 0.15600534827459206 and parameters: {'C': 16.504940302334166, 'class_weight': 'balanced', 'max_iter': 106}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:13:44,382] Trial 49 finished with value: 0.15504421222915482 and parameters: {'C': 3.877820537057415, 'class_weight': 'balanced', 'max_iter': 302}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:13:46,154] Trial 50 finished with value: 0.15468141788444395 and parameters: {'C': 0.1040336281763293, 'class_weight': 'balanced', 'max_iter': 694}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:13:47,965] Trial 51 finished with value: 0.15525199546839585 and parameters: {'C': 0.19162458364894405, 'class_weight': 'balanced', 'max_iter': 492}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:13:49,706] Trial 52 finished with value: 0.15467772572281938 and parameters: {'C': 0.3072308029977814, 'class_weight': 'balanced', 'max_iter': 384}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:13:51,431] Trial 53 finished with value: 0.1566486004181816 and parameters: {'C': 0.8339193302916991, 'class_weight': 'balanced', 'max_iter': 453}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:13:53,162] Trial 54 finished with value: 0.15515599058866741 and parameters: {'C': 1.9122239273398995, 'class_weight': 'balanced', 'max_iter': 449}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:13:54,902] Trial 55 finished with value: 0.15664081501224988 and parameters: {'C': 0.7138493461704877, 'class_weight': 'balanced', 'max_iter': 889}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:13:56,705] Trial 56 finished with value: 0.15500747230525105 and parameters: {'C': 3.5271303668071106, 'class_weight': 'balanced', 'max_iter': 153}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01
. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:14:39,570] Trial 79 finished with value: 0.15459683417869585 and parameters: {'C': 0.4382069050139926, 'class_weight': 'balanced', 'max_iter': 135}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:14:41,319] Trial 80 finished with value: 0.15662067086399034 and parameters: {'C': 0.861371409006944, 'class_weight': 'balanced', 'max_iter': 383}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:14:43,154] Trial 81 finished with value: 0.15661555665325652 and parameters: {'C': 0.7763271348265557, 'class_weight': 'balanced', 'max_iter': 242}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:14:44,988] Trial 82 finished with value: 0.15517307434374825 and parameters: {'C': 2.7794829125788563, 'class_weight': 'balanced', 'max_iter': 260}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:14:46,799] Trial 83 finished with value: 0.15506935793833226 and parameters: {'C': 1.6688020292425854, 'class_weight': 'balanced', 'max_iter': 310}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:14:48,617] Trial 84 finished with value: 0.15600847467773718 and parameters: {'C': 6.56209781050862, 'class_weight': 'balanced', 'max_iter': 197}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:14:50,417] Trial 85 finished with value: 0.15717697502144454 and parameters: {'C': 0.9525958614471636, 'class_weight': 'balanced', 'max_iter': 225}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:14:52,269] Trial 86 finished with value: 0.15561484820149413 and parameters: {'C': 0.21433924486416206, 'class_weight': 'balanced', 'max_iter': 273}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:14:54,268] Trial 87 finished with value: 0.15499193458564195 and parameters: {'C': 0.39506572192746464, 'class_weight': 'balanced', 'max_iter': 224}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:14:56,150] Trial 88 finished with value: 0.0 and parameters: {'C': 0.09142519840156348, 'class_weight': None, 'max_iter': 181}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:14:57,978] Trial 89 finished with value: 0.15644082782861077 and parameters: {'C': 1.0277025912213062, 'class_weight': 'balanced', 'max_iter': 464}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:14:59,754] Trial 90 finished with value: 0.15313726013923304 and parameters: {'C': 0.017442680966523235, 'class_weight': 'balanced', 'max_iter': 626}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:15:01,522] Trial 91 finished with value: 0.15656894948369604 and parameters: {'C': 0.5789831777574047, 'class_weight': 'balanced', 'max_iter': 287}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:15:03,263] Trial 92 finished with value: 0.15541916316293486 and parameters: {'C': 2.4182963013611296, 'class_weight': 'balanced', 'max_iter': 239}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:15:04,995] Trial 93 finished with value: 0.15661455742099548 and parameters: {'C': 0.7197653743547416, 'class_weight': 'balanced', 'max_iter': 254}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:15:06,825] Trial 94 finished with value: 0.155568773953654 and parameters: {'C': 1.2841946875403956, 'class_weight': 'balanced', 'max_iter': 342}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:15:08,697] Trial 95 finished with value: 0.15636952312079105 and parameters: {'C': 0.1451846313493101, 'class_weight': 'balanced', 'max_iter': 134}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:15:10,847] Trial 96 finished with value: 0.15528484872589515 and parameters: {'C': 4.518430414930607, 'class_weight': 'balanced', 'max_iter': 309}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:15:12,871] Trial 97 finished with value: 0.1518430884025122 and parameters: {'C': 0.003245703078343412, 'class_weight': 'balanced', 'max_iter': 211}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:15:14,957] Trial 98 finished with value: 0.15587398689797566 and parameters: {'C': 0.2587352026939227, 'class_weight': 'balanced', 'max_iter': 398}. Best is trial 45 with value: 0.15719259140971192.
# [I 2025-07-02 01:15:17,076] Trial 99 finished with value: 0.1554981195316505 and parameters: {'C': 0.032900832547299384, 'class_weight': 'balanced', 'max_iter': 170}. Best is trial 45 with value: 0.15719259140971192.
# Best Stacking score: 0.15719259140971192
# Best Stacking params: {'C': 0.13754162540171044, 'class_weight': 'balanced', 'max_iter': 458}
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
